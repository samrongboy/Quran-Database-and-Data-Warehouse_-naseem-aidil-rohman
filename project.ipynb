# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'project2'
DB_USER = 'postgres'
DB_PASSWORD = '631437007'
DB_PORT = '2002'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# postgresql://postgres:631437007@127.0.0.1:2002/project2

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS arabic (index int PRIMARY KEY,surah int,ayah int, text varchar);
# COPY arabic FROM 'D:\project404/arabic.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# Done.
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UniqueViolation: duplicate key value violates unique constraint "arabic_pkey"
# DETAIL:  Key (index)=(1) already exists.
# CONTEXT:  COPY arabic, line 2
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-48-da49facdb8b5> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "CREATE TABLE IF NOT EXISTS arabic (index int PRIMARY KEY,surah int,ayah int, text varchar);\nCOPY arabic FROM 'D:\\project404/arabic.csv' DELIMITER ',' CSV HEADER;\n")
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2380             with self.builtin_trap:
#    2381                 args = (magic_arg_s, cell)
# -> 2382                 result = fn(*args, **kwargs)
#    2383             return result
#    2384
#
# <decorator-gen-119> in execute(self, line, cell, local_ns)
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-118> in execute(self, line, cell, local_ns)
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     365             else:
#     366                 txt = sqlalchemy.sql.text(statement)
# --> 367                 result = conn.session.execute(txt, user_namespace)
#     368             _commit(conn=conn, config=config)
#     369             if result and config.feedback:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "arabic_pkey"
# DETAIL:  Key (index)=(1) already exists.
# CONTEXT:  COPY arabic, line 2
#
# [SQL: COPY arabic FROM 'D:\project404/arabic.csv' DELIMITER ',' CSV HEADER;]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS quran_surah (surah_id int PRIMARY KEY,arabic varchar, latin varchar,english varchar,sajda varchar,ayah int,types varchar);
# COPY PUBLIC.quran_surah FROM 'D:\project404/quran_surah.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# Done.
# 114 rows affected.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS translate (index int PRIMARY KEY,surah int, ayah int,th_translate varchar,en_translate varchar,mal_translate varchar,id_translate varchar,kh_translate varchar);
# COPY PUBLIC.translate FROM 'D:\project404/translate.csv' DELIMITER ',' CSV HEADER;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# Done.
# 6236 rows affected.
# []

# %%
# %%sql
# ALTER TABLE arabic
# ADD CONSTRAINT fk_surah FOREIGN KEY(surah)
# REFERENCES quran_surah(surah_id);
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# Done.
# []

# %%
# %%sql
# SELECT arabic.surah,quran_surah.arabic as surah_arabic,quran_surah.latin as surah_latin,
# arabic.ayah,arabic.text as arabic,
# translate.th_translate,
# translate.mal_translate,
# translate.id_translate,
# translate.kh_translate
# FROM arabic
# JOIN quran_surah ON arabic.surah = quran_surah.surah_id
# JOIN translate ON arabic.index = translate.index
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 10 rows affected.
# [(1, 'سورة الفاتحة', 'Al-Fatiha', 1, 'بِسۡمِ ٱللَّهِ ٱلرَّحۡمَٰنِ ٱلرَّحِيمِ', 'ด้วยพระนามของอัลลอฮฺ ผู้ทรงกรุณาปราณี ผู้ทรงเมตตาเสมอ', '  Dengan nama Allah  Yang Maha Pemurah  lagi Maha Mengasihani.        ', 'Dengan nama Allah Yang Maha Pengasih, Maha Penyayang.', ' ក្នុងនាមអល់ឡោះមហាសប្បុរស មហាអាណិតស្រឡាញ់។'),
#  (1, 'سورة الفاتحة', 'Al-Fatiha', 2, 'ٱلۡحَمۡدُ لِلَّهِ رَبِّ ٱلۡعَٰلَمِينَ', 'การสรรเสริญทั้งหลายนั้น เป็นสิทธิของอัลลอฮฺผู้เป็นพระเจ้าแห่งสากลโลก', '  Segala puji tertentu bagi Allah  Tuhan yang memelihara dan mentadbirkan sekalian alam.        ', 'Segala puji bagi Allah, Tuhan seluruh alam,', ' រាល់ការសរសើរ គឺចំពោះអល់ឡោះដែលជាម្ចាស់គ្រប់គ្រង ពិភពទាំងអស់។'),
#  (1, 'سورة الفاتحة', 'Al-Fatiha', 3, 'ٱلرَّحۡمَٰنِ ٱلرَّحِيمِ', 'ผู้ทรงกรุณาปราณี ผู้ทรงเมตตาเสมอ', '  Yang Maha Pemurah  lagi Maha Mengasihani.        ', 'Yang Maha Pengasih, Maha Penyayang,', ' ជាម្ចាស់មហាសប្បុរស មហាអាណិតស្រឡាញ់។'),
#  (1, 'سورة الفاتحة', 'Al-Fatiha', 4, 'مَٰلِكِ يَوۡمِ ٱلدِّينِ', 'ผู้ทรงอภิสิทธิ์แห่งวันตอบแทน', '  Yang Menguasai pemerintahan hari Pembalasan (hari Akhirat).        ', 'Pemilik hari pembalasan.1)', ' ជាសេ្ដច(គ្រប់គ្រង)នៃថ្ងៃជំនុំជំរះ(បរលោក)។'),
#  (1, 'سورة الفاتحة', 'Al-Fatiha', 5, 'إِيَّاكَ نَعۡبُدُ وَإِيَّاكَ نَسۡتَعِينُ', 'เฉพาะพระองค์เท่านั้นที่พวกข้าพระองค์เคารพอิบาดะฮฺ และเฉพาะพระองค์เท่านั้นที่พวกข้าพระองค์ขอความช่วยเหลือ', '  Engkaulah sahaja (Ya Allah) Yang Kami sembah  dan kepada Engkaulah sahaja kami memohon pertolongan.        ', 'Hanya kepada Engkaulah kami menyembah dan hanya kepada Engkaulah kami mohon pertolongan.', ' ចំពោះទ្រង់តែមួយគត់ដែលពួកយើងគោរពសក្ការៈ ហើយ ចំពោះទ្រង់តែមួយគត់ដែលពួកយើងសុំឱ្យជួយ។'),
#  (1, 'سورة الفاتحة', 'Al-Fatiha', 6, 'ٱهۡدِنَا ٱلصِّرَٰطَ ٱلۡمُسۡتَقِيمَ', 'ขอพระองค์ทรงแนะนำพวกข้าพระองค์ซึ่งทางอันเที่ยงตรง', '  Tunjukilah kami jalan yang lurus.        ', 'Tunjukilah kami jalan yang lurus,2)', ' សូមទ្រង់មេត្ដាចង្អុលបង្ហាញដល់ពួកយើងនូវមាគ៌ា ដ៏ត្រឹម ត្រូវផងចុះ។'),
#  (1, 'سورة الفاتحة', 'Al-Fatiha', 7, 'صِرَٰطَ ٱلَّذِينَ أَنۡعَمۡتَ عَلَيۡهِمۡ غَيۡرِ ٱلۡمَغۡضُوبِ عَلَيۡهِمۡ وَلَا ٱلضَّآلِّينَ', '(คือ) ทางของบรรดาผู้ที่พระองค์ได้ทรงโปรดปราณแก่พวกเขา มิใช่ในทางของพวกที่ถูกกริ้ว และมิใช่ทางของพวกที่หลงผิด', '  Iaitu jalan orang-orang yang Engkau telah kurniakan nikmat kepada mereka  bukan (jalan) orang-orang yang Engkau telah murkai  dan bukan pula (jalan) orang-orang yang sesat.        ', '(yaitu) jalan orang-orang yang telah Engkau beri nikmat kepadanya; bukan (jalan) mereka yang dimurkai, dan bukan (pula jalan) mereka yang sesat.3)', ' គឺមាគ៌ា របស់បណ្ដាអ្នកដែលទ្រង់បានប្រទាននៀកម៉ាត់ ដល់ពួកគេ ពុំមែនជា(មាគ៌ា)អ្នកដែលត្រូវគេខឹងសម្បា និងពុំមែន ជា(មាគ៌ា)ពួកដែលវងេ្វងឡើយ។'),
#  (2, 'سورة البقرة', 'Al-Baqara', 1, 'الٓمٓ', 'อะลิฟ ลาม มีม', '  Alif  Laam  Miim.        ', 'Alif LÄ\x81m MÄ«m.4)', ' អាលីហ្វ ឡាម មីម។'),
#  (2, 'سورة البقرة', 'Al-Baqara', 2, 'ذَٰلِكَ ٱلۡكِتَٰبُ لَا رَيۡبَۛ فِيهِۛ هُدٗى لِّلۡمُتَّقِينَ', 'คัมภีร์นี้ ไม่มีความสงสัยใด ๆ ในนั้น เป็นคำแนะนำสำหรับบรรดาผู้ยำเกรงเท่านั้น', '  Kitab Al-Quran ini  tidak ada sebarang syak padanya (tentang datangnya dari Allah dan tentang sempurnanya); ia pula menjadi petunjuk bagi orang-orang yang (hendak) bertaqwa;        ', 'Kitab (Al-Qur`an) ini tidak ada keraguan padanya; petunjuk bagi mereka yang bertakwa,5)', ' នេះគឺជាគម្ពីរ(គួរអាន)ដែលគ្មានការសង្ស័យឡើយនៅ ក្នុងវា។ វាគឺជាការចង្អុលបង្ហាញចំពោះបណ្ដាអ្នកដែលកោតខ្លាចអល់ឡោះ។'),
#  (2, 'سورة البقرة', 'Al-Baqara', 3, 'ٱلَّذِينَ يُؤۡمِنُونَ بِٱلۡغَيۡبِ وَيُقِيمُونَ ٱلصَّلَوٰةَ وَمِمَّا رَزَقۡنَٰهُمۡ يُنفِقُونَ', 'คือบรรดาผู้ศรัทธาต่อสิ่งเร้นลับ และดำรงไว้ซึ่งการละหมาด และส่วนหนึ่งจากสิ่งที่เราได้ให้เป็นปัจจัยยังชีพแก่พวกเขานั้น พวกเขาก็บริจาค', '  Iaitu orang-orang yang beriman kepada perkara-perkara yang ghaib  dan mendirikan (mengerjakan) sembahyang serta membelanjakan (mendermakan) sebahagian dari rezeki yang Kami berikan kepada mereka.        ', '(Yaitu) mereka yang beriman kepada yang gaib, melaksanakan salat, dan menginfakkan6) sebagian rezeki yang Kami berikan kepada mereka,', ' គឺបណ្ដាអ្នកដែលមានជំនឿនឹងប្រការអាថ៌កំបាំង ហើយ ប្រតិបត្ដិសឡាតនិងបរិច្ចាគមួយចំនួននូវអ្វីដែលយើងបានប្រទានឱ្យពួកគេ។')]

# %%
# %%sql
# SELECT arabic.surah, quran_surah.latin as latin, quran_surah.sajda as ayah_sajda
# FROM arabic
# JOIN quran_surah ON arabic.surah = quran_surah.surah_id
# WHERE quran_surah.sajda != '0'
# GROUP BY  arabic.surah,latin,ayah_sajda
# ORDER BY arabic.surah ASC
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 14 rows affected.
# [(7, 'Al-Araf', '206'),
#  (13, 'Ar-Rad', '15'),
#  (16, 'An-Nahl', '50'),
#  (17, 'Al-Isra', '100'),
#  (19, 'Maryam', '58'),
#  (22, 'Al-Hajj', '18'),
#  (25, 'Al-Furqan', '60'),
#  (27, 'An-Naml', '26'),
#  (32, 'As-Sajda', '15'),
#  (38, 'Sad', '24'),
#  (41, 'Fussilat', '38'),
#  (53, 'An-Najm', '62'),
#  (84, 'Al-Inshiqaq', '21'),
#  (96, 'Al-Alaq', '19')]

# %%
# %%sql
# select surah_id,latin,ayah from quran_surah where ayah < 20
# limit 10 ;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 10 rows affected.
# [(1, 'Al-Fatiha', 7),
#  (49, 'Al-Hujraat', 18),
#  (60, 'Al-Mumtahina', 13),
#  (61, 'As-Saff', 14),
#  (62, 'Al-Jumua', 11),
#  (63, 'Al-Munafiqoon', 11),
#  (64, 'At-Taghabun', 18),
#  (65, 'At-Talaq', 12),
#  (66, 'At-Tahrim', 12),
#  (82, 'AL-Infitar', 19)]

# %%
# %%sql
# select surah_id,latin,ayah from quran_surah where ayah > 100
# limit 10 ;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 10 rows affected.
# [(2, 'Al-Baqara', 286),
#  (3, 'Aal-e-Imran', 200),
#  (4, 'An-Nisa', 176),
#  (5, 'Al-Maeda', 120),
#  (6, 'Al-Anaam', 165),
#  (7, 'Al-Araf', 206),
#  (9, 'At-Taubah', 129),
#  (10, 'Yunus', 109),
#  (11, 'Hud', 123),
#  (12, 'Yusuf', 111)]

# %%
# %%sql
# SELECT min(ayah) as min, max(ayah) as max from quran_surah;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 1 rows affected.
# [(3, 286)]

# %%
ayahmore  = %sql SELECT count(quran_surah),count(1) FROM quran_surah WHERE ayah < '10' ;
print("lessthan 10 ayahs in total =", ayahmore[0][0],'surah')
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 1 rows affected.
# lessthan 10 ayahs in total = 19 surah

# %%
# %%sql
# SELECT * FROM arabic WHERE arabic.text ='طسٓمٓ'
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 2 rows affected.
# [(2933, 26, 1, 'طسٓمٓ'), (3253, 28, 1, 'طسٓمٓ')]

# %%
# %%sql
# SELECT *  FROM translate WHERE translate.th_translate ='อะลิฟ ลาม มีม'
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 6 rows affected.
# [(8, 2, 1, 'อะลิฟ ลาม มีม', 'Alif LÄ\x81m MÄ«m.', '  Alif  Laam  Miim.        ', 'Alif LÄ\x81m MÄ«m.4)', ' អាលីហ្វ ឡាម មីម។'),
#  (294, 3, 1, 'อะลิฟ ลาม มีม', 'Alif LÄ\x81m MÄ«m.', '  Alif  Laam  Miim.        ', 'Alif lÄ\x81m MÄ«m.', ' អាលីហ្វ ឡាម មីម ។'),
#  (3341, 29, 1, 'อะลิฟ ลาม มีม', 'Alif LÄ\x81m MÄ«m.', '  Alif  Laam  Miim.        ', 'Alif lÄ\x81m mÄ«m.', ' អាលីហ្វ ឡាម មីម។'),
#  (3410, 30, 1, 'อะลิฟ ลาม มีม', 'Alif LÄ\x81m MÄ«m.', '  Alif  Laam  Miim.        ', 'Alif LÄ\x81m MÄ«m.', ' អាលីហ្វ ឡាម មីម។'),
#  (3470, 31, 1, 'อะลิฟ ลาม มีม', 'Alif LÄ\x81m MÄ«m.', '  Alif  Laam  Miim.        ', 'Alif LÄ\x81m MÄ«m.', ' អាលីហ្វ ឡាម មីម។'),
#  (3504, 32, 1, 'อะลิฟ ลาม มีม', 'Alif LÄ\x81m MÄ«m.', '  Alif  Laam Miim.        ', 'Alif LÄ\x81m MÄ«m', ' អាលីហ្វ ឡាម មីម។')]

# %%
# %%sql
# select * from translate limit 5;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 5 rows affected.
# [(1, 1, 1, 'ด้วยพระนามของอัลลอฮฺ ผู้ทรงกรุณาปราณี ผู้ทรงเมตตาเสมอ', 'In the name of Allah, the Most Compassionate, the Most Merciful.', '  Dengan nama Allah  Yang Maha Pemurah  lagi Maha Mengasihani.        ', 'Dengan nama Allah Yang Maha Pengasih, Maha Penyayang.', ' ក្នុងនាមអល់ឡោះមហាសប្បុរស មហាអាណិតស្រឡាញ់។'),
#  (2, 1, 2, 'การสรรเสริญทั้งหลายนั้น เป็นสิทธิของอัลลอฮฺผู้เป็นพระเจ้าแห่งสากลโลก', 'All praise be to Allah, the Lord of the worlds,', '  Segala puji tertentu bagi Allah  Tuhan yang memelihara dan mentadbirkan sekalian alam.        ', 'Segala puji bagi Allah, Tuhan seluruh alam,', ' រាល់ការសរសើរ គឺចំពោះអល់ឡោះដែលជាម្ចាស់គ្រប់គ្រង ពិភពទាំងអស់។'),
#  (3, 1, 3, 'ผู้ทรงกรุณาปราณี ผู้ทรงเมตตาเสมอ', 'the Most Compassionate, the Most Merciful,', '  Yang Maha Pemurah  lagi Maha Mengasihani.        ', 'Yang Maha Pengasih, Maha Penyayang,', ' ជាម្ចាស់មហាសប្បុរស មហាអាណិតស្រឡាញ់។'),
#  (4, 1, 4, 'ผู้ทรงอภิสิทธิ์แห่งวันตอบแทน', 'Master of the Day of Judgment.', '  Yang Menguasai pemerintahan hari Pembalasan (hari Akhirat).        ', 'Pemilik hari pembalasan.1)', ' ជាសេ្ដច(គ្រប់គ្រង)នៃថ្ងៃជំនុំជំរះ(បរលោក)។'),
#  (5, 1, 5, 'เฉพาะพระองค์เท่านั้นที่พวกข้าพระองค์เคารพอิบาดะฮฺ และเฉพาะพระองค์เท่านั้นที่พวกข้าพระองค์ขอความช่วยเหลือ', 'You alone we worship, and You alone we ask for help.', '  Engkaulah sahaja (Ya Allah) Yang Kami sembah  dan kepada Engkaulah sahaja kami memohon pertolongan.        ', 'Hanya kepada Engkaulah kami menyembah dan hanya kepada Engkaulah kami mohon pertolongan.', ' ចំពោះទ្រង់តែមួយគត់ដែលពួកយើងគោរពសក្ការៈ ហើយ ចំពោះទ្រង់តែមួយគត់ដែលពួកយើងសុំឱ្យជួយ។')]

# %%
# %%sql
# select text as start from arabic
# limit 10;
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 10 rows affected.
# [('بِسۡمِ ٱللَّهِ ٱلرَّحۡمَٰنِ ٱلرَّحِيمِ',),
#  ('ٱلۡحَمۡدُ لِلَّهِ رَبِّ ٱلۡعَٰلَمِينَ',),
#  ('ٱلرَّحۡمَٰنِ ٱلرَّحِيمِ',),
#  ('مَٰلِكِ يَوۡمِ ٱلدِّينِ',),
#  ('إِيَّاكَ نَعۡبُدُ وَإِيَّاكَ نَسۡتَعِينُ',),
#  ('ٱهۡدِنَا ٱلصِّرَٰطَ ٱلۡمُسۡتَقِيمَ',),
#  ('صِرَٰطَ ٱلَّذِينَ أَنۡعَمۡتَ عَلَيۡهِمۡ غَيۡرِ ٱلۡمَغۡضُوبِ عَلَيۡهِمۡ وَلَا ٱلضَّآلِّينَ',),
#  ('الٓمٓ',),
#  ('ذَٰلِكَ ٱلۡكِتَٰبُ لَا رَيۡبَۛ فِيهِۛ هُدٗى لِّلۡمُتَّقِينَ',),
#  ('ٱلَّذِينَ يُؤۡمِنُونَ بِٱلۡغَيۡبِ وَيُقِيمُونَ ٱلصَّلَوٰةَ وَمِمَّا رَزَقۡنَٰهُمۡ يُنفِقُونَ',)]

# %%
# %%sql
# select th_translate, count(1)
# from translate
# group by th_translate
# order by count(1) desc
# limit 27
# Out:
#  * postgresql://postgres:***@127.0.0.1:2002/project2
# 27 rows affected.
# [('ความหายนะในวันนั้นจงประสบแด่บรรดาผู้ปฏิเสธ', 10),
#  ('ดังนั้น ด้วยบุญคุณอันใดเล่าแห่งพระเจ้าของเจ้าทั้งสองที่เจ้าทั้งสองปฏิเสธ?', 7),
#  ('ดังนั้นด้วยบุญคุณอันใดเล่าแห่งพระเจ้าของเจ้าทั้งสองที่เจ้าทั้งสองปฏิเสธ?', 7),
#  ('อะลิฟ ลาม มีม', 6),
#  ('ดังนั้นพวกท่านจงยำเกรงอัลลอฮ์ และเชื่อฟังฉัน', 6),
#  ('แท้จริงฉันคือร่อซูลผู้ซื่อสัตย์สำหรับพวกท่าน', 4),
#  ('เว้นแต่ปวงบ่าวของอัลลอฮฺผู้ซื่อสัตย์', 3),
#  ('ดังนั้นด้วยบุญคุณอันใดเล่าแห่งพระเจ้าของเจ้าทั้งสองที่เจ้าทั้งสองปฏิเสธ', 3),
#  ('แท้จริงในการนี้ย่อมเป็นสัญญาณหนึ่งอย่างแน่นอน แต่ส่วนมากของพวกเขาไม่เป็นผู้ศรัทธา', 3),
#  ('และเราได้ปล่อยทิ้งไว้ (เกียรติคุณ) แก่เขาในกลุ่มชนรุ่นหลัง ๆ', 3),
#  ('ฮามีม', 3),
#  ('และโดยแน่นอน เราได้ทำให้อัลกุรอานนี้เป็นที่เข้าใจง่ายแก่การรำลึก แล้วมีผู้ใดบ้างที่รับข้อตักเตือนนั้น', 3),
#  ('แท้จริง เช่นนั้นแหละเราจะตอบแทนผู้กระทำความดีทั้งหลาย', 3),
#  ('และบรรดาภูเขาจะเป็นเช่นขนสัตว์ที่ปลิวว่อน', 2),
#  ('และแท้จริงพระเจ้าของเจ้านั้น แน่นอนพระองค์เป็นผู้ทรงอำนาจ ผู้ทรงเมตตาเสมอ', 2),
#  ('เมื่อชั้นฟ้าได้แตกแยกออก', 2),
#  ('ดังนั้น ด้วยบุญคุณอันใดเล่าแห่งพระเจ้าของเจ้าทั้งสองที่เจ้าทั้งสองปฏิเสธ', 2),
#  ('และฉันมิได้ขอค่าตอบแทนในการนี้จากพวกท่าน ค่าตอบแทนของฉันมิได้มาจากผู้ใดนอกจากพระเจ้าแห่งสากลโลก', 2),
#  ('ฏอ ซีน มีม', 2),
#  ('และฉันมิได้ขอค่าตอบแทนในการนี้จากพวกท่าน ค่าตอบแทนของฉันมิได้มาจากผู้ใด นอกจากพระเจ้าแห่งสากลโลก', 2),
#  ('และเมื่อบรรดาดวงดาวร่วงหล่นลงมากระจัดกระจาย', 2),
#  ('ขอสาบานด้วยคัมภีร์อันชัดแจ้ง', 2),
#  ('คือบันทึกที่ถูกจารึกไว้', 2),
#  ('ฮา มีม', 2),
#  ('เขากล่าวว่า “ฉันมิได้บอกหรือว่า แท้จริงท่านจะไม่สามารถมีความอดทนร่วมกับฉันได้”', 2),
#  ('และแท้จริงพระเจ้าของเจ้านั้น แน่นอนพระองค์เป็นผู้ทรงเดชานุภาพ ผู้ทรงเมตตาเสมอ', 2),
#  ('พระองค์ตรัสว่า “ดังนั้น แท้จริงเจ้าอยู่ในหมู่ผู้ถูกประวิงเวลา”', 2)]
